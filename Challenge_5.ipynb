# %% [markdown]
# ---
# ##5.&nbsp; Challenge: apply this to the spotify dataset 😃
# Use PCA to reduce noise and the dimensionality of the Spotify dataset before clustering the songs. This will help to identify the most important features of the songs, and it will also make the clustering process more efficient.
#
# Once you have clustered the songs using the selected principal components, you can analyse the clusters to identify groups of similar songs. For example, you could look for clusters of songs with similar genres, tempos, or moods.

# %% [markdown]
# # Principal Component Analysis (PCA)
#
#
# PCA can be used to improve the performance of clustering algorithms, as well as to reduce the computational complexity.

# %% [markdown]
# # import Librarys

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.datasets import make_blobs

from sklearn import set_config
set_config(transform_output="pandas")

# %% [markdown]
# # import Data

# %%
url = '/Users/sadiakhanrupa/Bootcamp Main Phase/Chapter 6 Unsupervised ML/data/6.3.3_spotify_5000_songs.csv'
songs_df = pd.read_csv(url)
songs_df.tail()
# Out:
#       Unnamed: 0  \
# 5230        5230
# 5231        5231
# 5232        5232
# 5233        5233
# 5234        5234
#
#      name                                                                                                                                                                               \
# 5230  1812 Festival Overture, Op. 49: 1812 Overture,...
# 5231  Winter Fragments pour ensemble instrumental, s...
# 5232  Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3...
# 5233  Serenade For Strings In E, Op.22, B. 52: 1. Mo...
# 5234  Ravel: Boléro, M. 81                          ...
#
#       artist                                            danceability   \
# 5230  Pyotr Ilyich Tchaikovsky                                 0.2020
# 5231  Tristan Murail                                           0.1880
# 5232  Arnold Schoenberg                                        0.0596
# 5233  Antonín Dvořák                                           0.1330
# 5234  Maurice Ravel                                            0.3540
#
#       energy     key   loudness   mode   speechiness   acousticness   \
# 5230    0.06940     3    -23.390      1        0.0473          0.917
# 5231    0.10100     6    -21.873      1        0.0442          0.855
# 5232    0.00093     9    -42.959      1        0.0434          0.951
# 5233    0.02080     4    -29.443      1        0.0419          0.883
# 5234    0.04870     5    -24.568      1        0.0323          0.783
#
#       instrumentalness   liveness   valence   tempo     type   duration_ms   \
# 5230              0.715     0.0832    0.0655    87.906               995000
# 5231              0.426     0.0694    0.0355    83.134               855000
# 5232              0.969     0.0772    0.0344    71.573               238187
# 5233              0.505     0.1110    0.0591    67.109               314307
# 5234              0.484     0.2840    0.2530    64.120               948787
#
#       time_signature   id                       \
# 5230                4  1aEhYlZtypmipA06SDJ4U3
# 5231                4  1Gfqe7TAKklmuZf6hxsH6h
# 5232                3  2XNwnFrdMDpismp0VUZ7cU
# 5233                4  7ucDwgMtE3YJtEfTbuRhy0
# 5234                3  7E1ErYYCn0lYjHODZ1qGuB
#
#                                                    html
# 5230  https://open.spotify.com/track/1aEhYlZtypmipA0...
# 5231  https://open.spotify.com/track/1Gfqe7TAKklmuZf...
# 5232  https://open.spotify.com/track/2XNwnFrdMDpismp...
# 5233  https://open.spotify.com/track/7ucDwgMtE3YJtEf...
# 5234  https://open.spotify.com/track/7E1ErYYCn0lYjHO...

# %% [markdown]
# # Clean Data

# %%
songs_df.columns
# Out:
# Index(['Unnamed: 0',
#        'name                                                                                                                                                                             ',
#        'artist                                          ', 'danceability ',
#        'energy   ', 'key ', 'loudness ', 'mode ', 'speechiness ',
#        'acousticness ', 'instrumentalness ', 'liveness ', 'valence ',
#        'tempo   ', 'type ', 'duration_ms ', 'time_signature ',
#        'id                     ', 'html'],
#       dtype='object')

# %%
songs_df.columns = songs_df.columns.str.replace(' ', '')

# %%
songs_df_cl = songs_df.drop(columns=['Unnamed:0', 'type', 'id', 'html'])
songs_df_cl
# Out:
#                                                    name  \
# 0     Se Eu Quiser Falar Com Deus                   ...
# 1     Saudade De Bahia                              ...
# 2     Canta Canta, Minha Gente                      ...
# 3     Mulher Eu Sei                                 ...
# 4     Rosa Morena                                   ...
# ...                                                 ...
# 5230  1812 Festival Overture, Op. 49: 1812 Overture,...
# 5231  Winter Fragments pour ensemble instrumental, s...
# 5232  Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3...
# 5233  Serenade For Strings In E, Op.22, B. 52: 1. Mo...
# 5234  Ravel: Boléro, M. 81                          ...
#
#                                                 artist  danceability   energy  \
# 0     Gilberto Gil                                            0.6580  0.25900
# 1     Antônio Carlos Jobim                                    0.7420  0.39900
# 2     Martinho Da Vila                                        0.8510  0.73000
# 3     Chico César                                             0.7050  0.05020
# 4     Kurt Elling                                             0.6510  0.11900
# ...                                                ...           ...      ...
# 5230  Pyotr Ilyich Tchaikovsky                                0.2020  0.06940
# 5231  Tristan Murail                                          0.1880  0.10100
# 5232  Arnold Schoenberg                                       0.0596  0.00093
# 5233  Antonín Dvořák                                          0.1330  0.02080
# 5234  Maurice Ravel                                           0.3540  0.04870
#
#       key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0      11   -13.141     0       0.0705         0.694          0.000059
# 1       2   -12.646     1       0.0346         0.217          0.000002
# 2       2   -11.048     1       0.3470         0.453          0.000063
# 3       4   -18.115     1       0.0471         0.879          0.000041
# 4       6   -19.807     1       0.0380         0.916          0.000343
# ...   ...       ...   ...          ...           ...               ...
# 5230    3   -23.390     1       0.0473         0.917          0.715000
# 5231    6   -21.873     1       0.0442         0.855          0.426000
# 5232    9   -42.959     1       0.0434         0.951          0.969000
# 5233    4   -29.443     1       0.0419         0.883          0.505000
# 5234    5   -24.568     1       0.0323         0.783          0.484000
#
#       liveness  valence    tempo  duration_ms  time_signature
# 0       0.9750   0.3060  110.376       256213               4
# 1       0.1070   0.6930  125.039       191867               4
# 2       0.1240   0.9050   93.698       152267               4
# 3       0.3860   0.5240  106.802       186227               4
# 4       0.1040   0.4020  120.941       273680               4
# ...        ...      ...      ...          ...             ...
# 5230    0.0832   0.0655   87.906       995000               4
# 5231    0.0694   0.0355   83.134       855000               4
# 5232    0.0772   0.0344   71.573       238187               3
# 5233    0.1110   0.0591   67.109       314307               4
# 5234    0.2840   0.2530   64.120       948787               3
#
# [5235 rows x 15 columns]

# %% [markdown]
# # set index

# %%
#we want to set song name and artist as our index
songs_df_cl = songs_df_cl.set_index(['artist', 'name'])
songs_df_cl
# Out:
#                                                                                                      danceability  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...        0.6580
# Antônio Carlos Jobim                             Saudade De Bahia                               ...        0.7420
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...        0.8510
# Chico César                                      Mulher Eu Sei                                  ...        0.7050
# Kurt Elling                                      Rosa Morena                                    ...        0.6510
# ...                                                                                                           ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...        0.2020
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...        0.1880
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...        0.0596
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...        0.1330
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...        0.3540
#
#                                                                                                       energy  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  0.25900
# Antônio Carlos Jobim                             Saudade De Bahia                               ...  0.39900
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...  0.73000
# Chico César                                      Mulher Eu Sei                                  ...  0.05020
# Kurt Elling                                      Rosa Morena                                    ...  0.11900
# ...                                                                                                      ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...  0.06940
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...  0.10100
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.00093
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...  0.02080
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.04870
#
#                                                                                                      key  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...   11
# Antônio Carlos Jobim                             Saudade De Bahia                               ...    2
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...    2
# Chico César                                      Mulher Eu Sei                                  ...    4
# Kurt Elling                                      Rosa Morena                                    ...    6
# ...                                                                                                  ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...    3
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...    6
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...    9
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...    4
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...    5
#
#                                                                                                      loudness  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...   -13.141
# Antônio Carlos Jobim                             Saudade De Bahia                               ...   -12.646
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...   -11.048
# Chico César                                      Mulher Eu Sei                                  ...   -18.115
# Kurt Elling                                      Rosa Morena                                    ...   -19.807
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...   -23.390
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...   -21.873
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...   -42.959
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...   -29.443
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...   -24.568
#
#                                                                                                      mode  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...     0
# Antônio Carlos Jobim                             Saudade De Bahia                               ...     1
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...     1
# Chico César                                      Mulher Eu Sei                                  ...     1
# Kurt Elling                                      Rosa Morena                                    ...     1
# ...                                                                                                   ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...     1
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...     1
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...     1
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...     1
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...     1
#
#                                                                                                      speechiness  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...       0.0705
# Antônio Carlos Jobim                             Saudade De Bahia                               ...       0.0346
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...       0.3470
# Chico César                                      Mulher Eu Sei                                  ...       0.0471
# Kurt Elling                                      Rosa Morena                                    ...       0.0380
# ...                                                                                                          ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...       0.0473
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...       0.0442
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...       0.0434
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...       0.0419
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...       0.0323
#
#                                                                                                      acousticness  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...         0.694
# Antônio Carlos Jobim                             Saudade De Bahia                               ...         0.217
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...         0.453
# Chico César                                      Mulher Eu Sei                                  ...         0.879
# Kurt Elling                                      Rosa Morena                                    ...         0.916
# ...                                                                                                           ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...         0.917
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...         0.855
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...         0.951
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...         0.883
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...         0.783
#
#                                                                                                      instrumentalness  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...          0.000059
# Antônio Carlos Jobim                             Saudade De Bahia                               ...          0.000002
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...          0.000063
# Chico César                                      Mulher Eu Sei                                  ...          0.000041
# Kurt Elling                                      Rosa Morena                                    ...          0.000343
# ...                                                                                                               ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...          0.715000
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...          0.426000
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...          0.969000
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...          0.505000
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...          0.484000
#
#                                                                                                      liveness  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...    0.9750
# Antônio Carlos Jobim                             Saudade De Bahia                               ...    0.1070
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...    0.1240
# Chico César                                      Mulher Eu Sei                                  ...    0.3860
# Kurt Elling                                      Rosa Morena                                    ...    0.1040
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...    0.0832
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...    0.0694
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...    0.0772
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...    0.1110
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...    0.2840
#
#                                                                                                      valence  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...   0.3060
# Antônio Carlos Jobim                             Saudade De Bahia                               ...   0.6930
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...   0.9050
# Chico César                                      Mulher Eu Sei                                  ...   0.5240
# Kurt Elling                                      Rosa Morena                                    ...   0.4020
# ...                                                                                                      ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...   0.0655
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...   0.0355
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...   0.0344
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...   0.0591
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...   0.2530
#
#                                                                                                        tempo  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  110.376
# Antônio Carlos Jobim                             Saudade De Bahia                               ...  125.039
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...   93.698
# Chico César                                      Mulher Eu Sei                                  ...  106.802
# Kurt Elling                                      Rosa Morena                                    ...  120.941
# ...                                                                                                      ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...   87.906
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...   83.134
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...   71.573
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...   67.109
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...   64.120
#
#                                                                                                      duration_ms  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...       256213
# Antônio Carlos Jobim                             Saudade De Bahia                               ...       191867
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...       152267
# Chico César                                      Mulher Eu Sei                                  ...       186227
# Kurt Elling                                      Rosa Morena                                    ...       273680
# ...                                                                                                          ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...       995000
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...       855000
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...       238187
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...       314307
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...       948787
#
#                                                                                                      time_signature
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...               4
# Antônio Carlos Jobim                             Saudade De Bahia                               ...               4
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...               4
# Chico César                                      Mulher Eu Sei                                  ...               4
# Kurt Elling                                      Rosa Morena                                    ...               4
# ...                                                                                                             ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...               4
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...               4
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...               3
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...               4
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...               3
#
# [5235 rows x 13 columns]

# %% [markdown]
# # Scale the Data

# %%
scaler = MinMaxScaler().set_output(transform='pandas')
songs_df_cl_mm = scaler.fit_transform(songs_df_cl)
songs_df_cl_mm
# Out:
#                                                                                                      danceability  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...      0.680455
# Antônio Carlos Jobim                             Saudade De Bahia                               ...      0.767322
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...      0.880041
# Chico César                                      Mulher Eu Sei                                  ...      0.729059
# Kurt Elling                                      Rosa Morena                                    ...      0.673216
# ...                                                                                                           ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...      0.208893
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...      0.194416
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...      0.061634
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...      0.137539
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...      0.366081
#
#                                                                                                       energy  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  0.25900
# Antônio Carlos Jobim                             Saudade De Bahia                               ...  0.39900
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...  0.73000
# Chico César                                      Mulher Eu Sei                                  ...  0.05020
# Kurt Elling                                      Rosa Morena                                    ...  0.11900
# ...                                                                                                      ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...  0.06940
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...  0.10100
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.00093
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...  0.02080
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.04870
#
#                                                                                                           key  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  1.000000
# Antônio Carlos Jobim                             Saudade De Bahia                               ...  0.181818
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...  0.181818
# Chico César                                      Mulher Eu Sei                                  ...  0.363636
# Kurt Elling                                      Rosa Morena                                    ...  0.545455
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...  0.272727
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...  0.545455
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.818182
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...  0.363636
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.454545
#
#                                                                                                      loudness  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  0.763897
# Antônio Carlos Jobim                             Saudade De Bahia                               ...  0.771967
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...  0.798018
# Chico César                                      Mulher Eu Sei                                  ...  0.682811
# Kurt Elling                                      Rosa Morena                                    ...  0.655228
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...  0.596818
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...  0.621548
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.277803
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...  0.498142
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.577614
#
#                                                                                                      mode  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...   0.0
# Antônio Carlos Jobim                             Saudade De Bahia                               ...   1.0
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...   1.0
# Chico César                                      Mulher Eu Sei                                  ...   1.0
# Kurt Elling                                      Rosa Morena                                    ...   1.0
# ...                                                                                                   ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...   1.0
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...   1.0
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...   1.0
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...   1.0
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...   1.0
#
#                                                                                                      speechiness  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...     0.076797
# Antônio Carlos Jobim                             Saudade De Bahia                               ...     0.037691
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...     0.377996
# Chico César                                      Mulher Eu Sei                                  ...     0.051307
# Kurt Elling                                      Rosa Morena                                    ...     0.041394
# ...                                                                                                          ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...     0.051525
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...     0.048148
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...     0.047277
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...     0.045643
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...     0.035185
#
#                                                                                                      acousticness  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...      0.696787
# Antônio Carlos Jobim                             Saudade De Bahia                               ...      0.217871
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...      0.454819
# Chico César                                      Mulher Eu Sei                                  ...      0.882530
# Kurt Elling                                      Rosa Morena                                    ...      0.919679
# ...                                                                                                           ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...      0.920683
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...      0.858434
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...      0.954819
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...      0.886546
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...      0.786145
#
#                                                                                                      instrumentalness  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...          0.000060
# Antônio Carlos Jobim                             Saudade De Bahia                               ...          0.000002
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...          0.000064
# Chico César                                      Mulher Eu Sei                                  ...          0.000041
# Kurt Elling                                      Rosa Morena                                    ...          0.000348
# ...                                                                                                               ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...          0.725888
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...          0.432487
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...          0.983756
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...          0.512690
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...          0.491371
#
#                                                                                                      liveness  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  0.987842
# Antônio Carlos Jobim                             Saudade De Bahia                               ...  0.108409
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...  0.125633
# Chico César                                      Mulher Eu Sei                                  ...  0.391084
# Kurt Elling                                      Rosa Morena                                    ...  0.105370
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...  0.084296
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...  0.070314
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.078217
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...  0.112462
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.287741
#
#                                                                                                       valence  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  0.310660
# Antônio Carlos Jobim                             Saudade De Bahia                               ...  0.703553
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...  0.918782
# Chico César                                      Mulher Eu Sei                                  ...  0.531980
# Kurt Elling                                      Rosa Morena                                    ...  0.408122
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...  0.066497
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...  0.036041
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.034924
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...  0.060000
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.256853
#
#                                                                                                         tempo  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  0.515800
# Antônio Carlos Jobim                             Saudade De Bahia                               ...  0.584322
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...  0.437862
# Chico César                                      Mulher Eu Sei                                  ...  0.499098
# Kurt Elling                                      Rosa Morena                                    ...  0.565171
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...  0.410795
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...  0.388495
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.334469
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...  0.313608
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.299640
#
#                                                                                                      duration_ms  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...     0.059067
# Antônio Carlos Jobim                             Saudade De Bahia                               ...     0.042058
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...     0.031590
# Chico César                                      Mulher Eu Sei                                  ...     0.040567
# Kurt Elling                                      Rosa Morena                                    ...     0.063684
# ...                                                                                                          ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...     0.254357
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...     0.217350
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...     0.054302
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...     0.074424
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...     0.242141
#
#                                                                                                      time_signature
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...             0.8
# Antônio Carlos Jobim                             Saudade De Bahia                               ...             0.8
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...             0.8
# Chico César                                      Mulher Eu Sei                                  ...             0.8
# Kurt Elling                                      Rosa Morena                                    ...             0.8
# ...                                                                                                             ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...             0.8
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...             0.8
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...             0.6
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...             0.8
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...             0.6
#
# [5235 rows x 13 columns]

# %% [markdown]
# # Baseline Model

# %% [markdown]
# >We will start by creating a basic k-means model. Later, we will apply PCA and compare the clusters to this baseline model to see if there is any difference.

# %%
# Initialise the model
my_kmeans = KMeans(n_clusters= 25, # you always choose the number of k here
                   n_init="auto",
                   random_state = 42)

# Fit the model to the data
my_kmeans.fit(songs_df_cl_mm)

# Obtain the cluster output
clusters = my_kmeans.labels_

# Attach the cluster output to a new DataFrame
clusters_df = pd.DataFrame(index=songs_df_cl.index,
                           data={"Base model": clusters})

clusters_df
# Out:
#                                                                                                      Base model
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...           2
# Antônio Carlos Jobim                             Saudade De Bahia                               ...          17
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...          16
# Chico César                                      Mulher Eu Sei                                  ...           7
# Kurt Elling                                      Rosa Morena                                    ...          24
# ...                                                                                                         ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...           0
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...          23
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...          23
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...           0
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...           0
#
# [5235 rows x 1 columns]

# %% [markdown]
# >As we saw on the LMS, PCA creates as many principal components as the original DataFrame has columns. We then need to decide how many of these components to keep. Before we do that, let's look at how PCA transforms our DataFrame.

# %%
# Initialise the PCA object
pca = PCA()

# Fit the PCA object to the data
pca.fit(songs_df_cl_mm)

# Transform scaled_features_df based on the fit calculations
pca_basic_df = pca.transform(songs_df_cl_mm)

pca_basic_df
# Out:
#                                                                                                          pca0  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ... -0.094419
# Antônio Carlos Jobim                             Saudade De Bahia                               ... -0.017481
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ... -0.126719
# Chico César                                      Mulher Eu Sei                                  ...  0.505367
# Kurt Elling                                      Rosa Morena                                    ...  0.542908
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...  1.177483
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...  0.974406
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  1.400419
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...  1.101864
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.900250
#
#                                                                                                          pca1  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  0.757884
# Antônio Carlos Jobim                             Saudade De Bahia                               ... -0.453019
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ... -0.504107
# Chico César                                      Mulher Eu Sei                                  ... -0.184282
# Kurt Elling                                      Rosa Morena                                    ... -0.131782
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...  0.113871
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...  0.069205
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.327087
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...  0.089709
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.022116
#
#                                                                                                          pca2  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ... -0.504083
# Antônio Carlos Jobim                             Saudade De Bahia                               ... -0.384560
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ... -0.471724
# Chico César                                      Mulher Eu Sei                                  ... -0.811681
# Kurt Elling                                      Rosa Morena                                    ... -0.744387
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ... -0.123871
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so... -0.211216
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.021031
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod... -0.222889
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ... -0.295232
#
#                                                                                                          pca3  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  0.438636
# Antônio Carlos Jobim                             Saudade De Bahia                               ... -0.225555
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ... -0.230476
# Chico César                                      Mulher Eu Sei                                  ... -0.006984
# Kurt Elling                                      Rosa Morena                                    ...  0.172948
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ... -0.106151
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...  0.173331
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.424738
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod... -0.004583
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.072579
#
#                                                                                                          pca4  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ... -0.257086
# Antônio Carlos Jobim                             Saudade De Bahia                               ...  0.082847
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...  0.276667
# Chico César                                      Mulher Eu Sei                                  ... -0.074671
# Kurt Elling                                      Rosa Morena                                    ... -0.151485
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ... -0.116104
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so... -0.305723
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.000413
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod... -0.271117
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ... -0.083580
#
#                                                                                                          pca5  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  0.554242
# Antônio Carlos Jobim                             Saudade De Bahia                               ... -0.174383
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ... -0.007994
# Chico César                                      Mulher Eu Sei                                  ...  0.106656
# Kurt Elling                                      Rosa Morena                                    ... -0.082936
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ... -0.081500
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so... -0.099305
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ... -0.089724
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod... -0.073719
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.003077
#
#                                                                                                          pca6  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  0.560851
# Antônio Carlos Jobim                             Saudade De Bahia                               ...  0.038690
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...  0.037417
# Chico César                                      Mulher Eu Sei                                  ...  0.223721
# Kurt Elling                                      Rosa Morena                                    ...  0.009560
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...  0.002337
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so... -0.023697
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ... -0.013262
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...  0.017510
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.196736
#
#                                                                                                          pca7  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  0.197453
# Antônio Carlos Jobim                             Saudade De Bahia                               ...  0.109702
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ... -0.139534
# Chico César                                      Mulher Eu Sei                                  ...  0.101924
# Kurt Elling                                      Rosa Morena                                    ...  0.093759
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ... -0.068789
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so... -0.105861
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ... -0.144308
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod... -0.163171
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ... -0.106103
#
#                                                                                                          pca8  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  0.102738
# Antônio Carlos Jobim                             Saudade De Bahia                               ...  0.174917
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ... -0.165436
# Chico César                                      Mulher Eu Sei                                  ...  0.086820
# Kurt Elling                                      Rosa Morena                                    ... -0.027305
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...  0.079293
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...  0.101755
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.239323
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...  0.201389
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.227768
#
#                                                                                                          pca9  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ... -0.022729
# Antônio Carlos Jobim                             Saudade De Bahia                               ... -0.011962
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...  0.016899
# Chico César                                      Mulher Eu Sei                                  ... -0.029381
# Kurt Elling                                      Rosa Morena                                    ... -0.032008
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ... -0.077375
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so... -0.077026
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.108310
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod... -0.084121
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.135509
#
#                                                                                                         pca10  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ... -0.013079
# Antônio Carlos Jobim                             Saudade De Bahia                               ... -0.017243
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...  0.289205
# Chico César                                      Mulher Eu Sei                                  ...  0.008400
# Kurt Elling                                      Rosa Morena                                    ... -0.005094
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...  0.018366
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...  0.011342
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.059216
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...  0.031439
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.013104
#
#                                                                                                         pca11  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ... -0.005804
# Antônio Carlos Jobim                             Saudade De Bahia                               ...  0.015519
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...  0.069875
# Chico César                                      Mulher Eu Sei                                  ...  0.013775
# Kurt Elling                                      Rosa Morena                                    ...  0.063066
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...  0.012382
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...  0.012386
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.248719
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...  0.087537
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.037266
#
#                                                                                                         pca12
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ... -0.006255
# Antônio Carlos Jobim                             Saudade De Bahia                               ... -0.011982
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ... -0.010251
# Chico César                                      Mulher Eu Sei                                  ... -0.021077
# Kurt Elling                                      Rosa Morena                                    ...  0.002000
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...  0.173650
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...  0.137500
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ... -0.038534
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod... -0.011667
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.165491
#
# [5235 rows x 13 columns]

# %% [markdown]
# >  we have the same amount of columns as before but we have lost the column names. This is because the columns are now principal components and not the original features (danceability, speechiness, etc...). Principal components are an abstraction of the original features, capturing the most significant patterns and trends within the data. They are like new axes along which the data is spread out, representing directions of maximum variance. The first principal component explains the largest amount of variance, followed by the second, and so on.

# %% [markdown]
# >>> Identifying the most informative principal components
# Principal component analysis (PCA) assumes that variance is information. This means that PCA believes that the directions in which the data varies the most are the most important.
#
# >>When we fit PCA to our data, it calculates all of the principal components. We can see how much variance each principal component explains using the `explained_variance_ratio_` attribute.
# >> The principal components are ranked in order of decreasing variance, with the first principal component explaining the most variance in the data

# %%
# Get the variance explained by each principal component
explained_variance_array = pca.explained_variance_ratio_

explained_variance_array
# Out:
# array([0.27948434, 0.26165474, 0.18337196, 0.11435786, 0.06083028,
#        0.0276579 , 0.0226709 , 0.01778696, 0.01492237, 0.0073763 ,
#        0.00603544, 0.00251644, 0.00133449])

# %% [markdown]
# To determine how many principal components to keep, we can use one of two methods:
#
# - **Elbow method**: This is a more manual approach where we plot the explained variance of each principal component against its index. The elbow point is the point at which the explained variance starts to drop off significantly. This is the point at which it is no longer worth retaining any more principal components, as they are not explaining much additional variance.
# - **Cumulative explained variance**: This is a more automated approach where SKLearn calculates how many principal components contain a given amount of variance, such as 95%.

# %% [markdown]
# # The elbow method works by plotting the variance of each principal component against its index.

# %%
# Create a Pandas DataFrame from the variance explained array
explained_variance_array_df = pd.DataFrame(explained_variance_array, columns=["Variance explained"])

# Add a column for the principal component index
explained_variance_array_df["Principal component index"] = range(len(explained_variance_array))

(
# Create a line chart with sns.relplot
sns.relplot(
    kind='line',
    data=explained_variance_array_df,
    x="Principal component index",
    y="Variance explained",
    marker='o',
    aspect=1.3)
# Set the title of the plot
.set(title="Proportion of variance explained by each principal component")
# Set the axis labels
.set_axis_labels("Principal component number", "Proportion of variance")
);
# Out:
# /Users/sadiakhanrupa/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# >Just like the elbow method used to determine the optimal number of clusters for k-means clustering, we are looking for a point where the decrease in variance levels off. This point, known as the elbow point, marks the point at which the explained variance starts to reduce significantly.

# %%
# Set the variable elbow to where you believe the elbow is
elbow = 6

# %% [markdown]
# >Let's make a DataFrame containing these principle components

# %%
# Create a PCA object with {elbow} principal components
# We add 1 as the principal components start at 0 and not 1
pca_elbow = PCA(n_components=elbow + 1)

# Fit the PCA object to the scaled features dataframe and transform it
pca_elbow_df = pca_elbow.fit_transform(songs_df_cl_mm)

# The dataframe now contains the principal components of the scaled features dataframe
pca_elbow_df
# Out:
#                                                                                                          pca0  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ... -0.094419
# Antônio Carlos Jobim                             Saudade De Bahia                               ... -0.017481
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ... -0.126719
# Chico César                                      Mulher Eu Sei                                  ...  0.505367
# Kurt Elling                                      Rosa Morena                                    ...  0.542908
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...  1.177483
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...  0.974406
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  1.400419
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...  1.101864
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.900250
#
#                                                                                                          pca1  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  0.757884
# Antônio Carlos Jobim                             Saudade De Bahia                               ... -0.453019
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ... -0.504107
# Chico César                                      Mulher Eu Sei                                  ... -0.184282
# Kurt Elling                                      Rosa Morena                                    ... -0.131782
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...  0.113871
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...  0.069205
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.327087
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...  0.089709
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.022116
#
#                                                                                                          pca2  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ... -0.504083
# Antônio Carlos Jobim                             Saudade De Bahia                               ... -0.384560
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ... -0.471724
# Chico César                                      Mulher Eu Sei                                  ... -0.811681
# Kurt Elling                                      Rosa Morena                                    ... -0.744387
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ... -0.123871
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so... -0.211216
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.021031
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod... -0.222889
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ... -0.295232
#
#                                                                                                          pca3  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  0.438636
# Antônio Carlos Jobim                             Saudade De Bahia                               ... -0.225555
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ... -0.230476
# Chico César                                      Mulher Eu Sei                                  ... -0.006984
# Kurt Elling                                      Rosa Morena                                    ...  0.172948
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ... -0.106151
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...  0.173331
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.424738
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod... -0.004583
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.072579
#
#                                                                                                          pca4  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ... -0.257086
# Antônio Carlos Jobim                             Saudade De Bahia                               ...  0.082847
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...  0.276667
# Chico César                                      Mulher Eu Sei                                  ... -0.074671
# Kurt Elling                                      Rosa Morena                                    ... -0.151485
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ... -0.116104
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so... -0.305723
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.000413
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod... -0.271117
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ... -0.083580
#
#                                                                                                          pca5  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  0.554242
# Antônio Carlos Jobim                             Saudade De Bahia                               ... -0.174383
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ... -0.007994
# Chico César                                      Mulher Eu Sei                                  ...  0.106656
# Kurt Elling                                      Rosa Morena                                    ... -0.082936
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ... -0.081500
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so... -0.099305
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ... -0.089724
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod... -0.073719
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.003077
#
#                                                                                                          pca6
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  0.560851
# Antônio Carlos Jobim                             Saudade De Bahia                               ...  0.038690
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...  0.037417
# Chico César                                      Mulher Eu Sei                                  ...  0.223721
# Kurt Elling                                      Rosa Morena                                    ...  0.009560
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...  0.002337
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so... -0.023697
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ... -0.013262
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...  0.017510
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.196736
#
# [5235 rows x 7 columns]

# %% [markdown]
# Let's compare the clusters made when using PCA to when not using PCA.
# > It's helpful to demonstrate this on a small dataset so you can easily grasp the concept of PCA before scaling up. However, it's unlikely we'll see a dramatic difference, if any, on such a small dataset. This is normal, and you shouldn't worry about it. As long as you understand the principle of what's happening, this will help you throughout the bootcamp as you learn about machine learning on larger datasets.

# %%
# Initialise the model
my_kmeans = KMeans(n_clusters= 25, # you always choose the number of k here
                   n_init="auto",
                   random_state = 42)

# Fit the model to the data
my_kmeans.fit(pca_elbow_df)

# Obtain the cluster output
clusters = my_kmeans.labels_

# Attach the cluster output to our clusters_df DataFrame
clusters_df[f"PCA - {elbow}"] = clusters

clusters_df
# Out:
#                                                                                                      Base model  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...           2
# Antônio Carlos Jobim                             Saudade De Bahia                               ...          17
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...          16
# Chico César                                      Mulher Eu Sei                                  ...           7
# Kurt Elling                                      Rosa Morena                                    ...          24
# ...                                                                                                         ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...           0
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...          23
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...          23
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...           0
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...           0
#
#                                                                                                      PCA - 9  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...       21
# Antônio Carlos Jobim                             Saudade De Bahia                               ...       11
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...       11
# Chico César                                      Mulher Eu Sei                                  ...       12
# Kurt Elling                                      Rosa Morena                                    ...        7
# ...                                                                                                      ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...        0
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...       10
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...       10
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...        0
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...       10
#
#                                                                                                      PCA - 0.95  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...          17
# Antônio Carlos Jobim                             Saudade De Bahia                               ...          21
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...           4
# Chico César                                      Mulher Eu Sei                                  ...           8
# Kurt Elling                                      Rosa Morena                                    ...           8
# ...                                                                                                         ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...           0
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...          22
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...          22
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...           0
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...          22
#
#                                                                                                      PCA - 6
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...       17
# Antônio Carlos Jobim                             Saudade De Bahia                               ...       21
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...        4
# Chico César                                      Mulher Eu Sei                                  ...        8
# Kurt Elling                                      Rosa Morena                                    ...        8
# ...                                                                                                      ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...        0
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...       22
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...       22
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...        0
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...       22
#
# [5235 rows x 4 columns]

# %% [markdown]
# >Cumulative explained variance
# Cumulative explained variance (CEV) is calculated by summing the explained variance of each principal component. The CEV plot shows how much variance is explained by each principal component, as well as the cumulative variance explained by all principal components up to that point.

# %%
(
# Create a cumulative explained variance plot
sns.relplot(
    kind="line",  # Create a line plot
    x=np.arange(len(explained_variance_array)),  # Set the x-axis to be the principal component index
    y=np.cumsum(explained_variance_array),  # Set the y-axis to be the cumulative explained variance
    marker="o",  # Use a circle marker for the data points
    aspect=1.4,  # Set the aspect ratio of the plot to be 1.4
)
# Set the title of the plot
.set(title="Cumulative explained variance of principal components")
# Set the axis labels
.set_axis_labels("Principal component", "Cumulative explained variance")
);
# Out:
# /Users/sadiakhanrupa/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# We can also look for an elbow in the cumulative variance plot to determine how many principal components to retain. However, instead of doing that, we will set a cumulative variance threshold in the PCA constructor. This threshold tells scikit-learn how many principal components to retain. For example, 0.95 tells scikit-learn that we want to retain as many principle components as contain 95% or more of the variance.

# %%
# Create a PCA object
pca_variance = PCA(n_components=0.95)

# %% [markdown]
# >Let's visualise this threshold

# %%
(
# Create a cumulative explained variance plot
sns.relplot(
    kind="line",  # Create a line plot
    x=np.arange(len(explained_variance_array)),  # Set the x-axis to be the principal component index
    y=np.cumsum(explained_variance_array),  # Set the y-axis to be the cumulative explained variance
    marker="o",  # Use a circle marker for the data points
    aspect=1.4,  # Set the aspect ratio of the plot to be 1.4
)
# Set the title of the plot
.set(title="Cumulative explained variance of principal components")
# Set the axis labels
.set_axis_labels("Principal component", "Cumulative explained variance")
);

# Add a horizontal red line at 0.95 on the y axis
plt.axhline(y=0.95,
            color='red');
# Out:
# /Users/sadiakhanrupa/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# >Let's apply this to our scaled data

# %%
# Fit the PCA object to the scaled features dataframe and transform it
pca_variance_df = pca_variance.fit_transform(songs_df_cl_mm)

# The dataframe now contains the principal components of the scaled features dataframe
pca_variance_df
# Out:
#                                                                                                          pca0  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ... -0.094419
# Antônio Carlos Jobim                             Saudade De Bahia                               ... -0.017481
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ... -0.126719
# Chico César                                      Mulher Eu Sei                                  ...  0.505367
# Kurt Elling                                      Rosa Morena                                    ...  0.542908
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...  1.177483
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...  0.974406
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  1.400419
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...  1.101864
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.900250
#
#                                                                                                          pca1  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  0.757884
# Antônio Carlos Jobim                             Saudade De Bahia                               ... -0.453019
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ... -0.504107
# Chico César                                      Mulher Eu Sei                                  ... -0.184282
# Kurt Elling                                      Rosa Morena                                    ... -0.131782
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...  0.113871
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...  0.069205
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.327087
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...  0.089709
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.022116
#
#                                                                                                          pca2  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ... -0.504083
# Antônio Carlos Jobim                             Saudade De Bahia                               ... -0.384560
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ... -0.471724
# Chico César                                      Mulher Eu Sei                                  ... -0.811681
# Kurt Elling                                      Rosa Morena                                    ... -0.744387
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ... -0.123871
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so... -0.211216
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.021031
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod... -0.222889
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ... -0.295232
#
#                                                                                                          pca3  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  0.438636
# Antônio Carlos Jobim                             Saudade De Bahia                               ... -0.225555
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ... -0.230476
# Chico César                                      Mulher Eu Sei                                  ... -0.006984
# Kurt Elling                                      Rosa Morena                                    ...  0.172948
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ... -0.106151
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...  0.173331
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.424738
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod... -0.004583
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.072579
#
#                                                                                                          pca4  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ... -0.257086
# Antônio Carlos Jobim                             Saudade De Bahia                               ...  0.082847
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...  0.276667
# Chico César                                      Mulher Eu Sei                                  ... -0.074671
# Kurt Elling                                      Rosa Morena                                    ... -0.151485
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ... -0.116104
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so... -0.305723
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...  0.000413
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod... -0.271117
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ... -0.083580
#
#                                                                                                          pca5  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  0.554242
# Antônio Carlos Jobim                             Saudade De Bahia                               ... -0.174383
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ... -0.007994
# Chico César                                      Mulher Eu Sei                                  ...  0.106656
# Kurt Elling                                      Rosa Morena                                    ... -0.082936
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ... -0.081500
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so... -0.099305
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ... -0.089724
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod... -0.073719
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.003077
#
#                                                                                                          pca6
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...  0.560851
# Antônio Carlos Jobim                             Saudade De Bahia                               ...  0.038690
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...  0.037417
# Chico César                                      Mulher Eu Sei                                  ...  0.223721
# Kurt Elling                                      Rosa Morena                                    ...  0.009560
# ...                                                                                                       ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...  0.002337
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so... -0.023697
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ... -0.013262
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...  0.017510
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...  0.196736
#
# [5235 rows x 7 columns]

# %% [markdown]
# Great! Now we can view the clusters created by this model alongside our baseline and elbow clusters.

# %%
# Initialise the model
my_kmeans = KMeans(n_clusters= 25, # you always choose the number of k here
                   n_init="auto",
                   random_state = 42)

# Fit the model to the data
my_kmeans.fit(pca_variance_df)

# Obtain the cluster output
clusters = my_kmeans.labels_

# Attach the cluster output to our clusters_df DataFrame
clusters_df["PCA - 0.95"] = clusters

clusters_df
# Out:
#                                                                                                      Base model  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...           2
# Antônio Carlos Jobim                             Saudade De Bahia                               ...          17
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...          16
# Chico César                                      Mulher Eu Sei                                  ...           7
# Kurt Elling                                      Rosa Morena                                    ...          24
# ...                                                                                                         ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...           0
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...          23
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...          23
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...           0
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...           0
#
#                                                                                                      PCA - 9  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...       21
# Antônio Carlos Jobim                             Saudade De Bahia                               ...       11
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...       11
# Chico César                                      Mulher Eu Sei                                  ...       12
# Kurt Elling                                      Rosa Morena                                    ...        7
# ...                                                                                                      ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...        0
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...       10
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...       10
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...        0
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...       10
#
#                                                                                                      PCA - 0.95  \
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...          17
# Antônio Carlos Jobim                             Saudade De Bahia                               ...          21
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...           4
# Chico César                                      Mulher Eu Sei                                  ...           8
# Kurt Elling                                      Rosa Morena                                    ...           8
# ...                                                                                                         ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...           0
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...          22
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...          22
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...           0
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...          22
#
#                                                                                                      PCA - 6
# artist                                           name
# Gilberto Gil                                     Se Eu Quiser Falar Com Deus                    ...       17
# Antônio Carlos Jobim                             Saudade De Bahia                               ...       21
# Martinho Da Vila                                 Canta Canta, Minha Gente                       ...        4
# Chico César                                      Mulher Eu Sei                                  ...        8
# Kurt Elling                                      Rosa Morena                                    ...        8
# ...                                                                                                      ...
# Pyotr Ilyich Tchaikovsky                         1812 Festival Overture, Op. 49: 1812 Overture, ...        0
# Tristan Murail                                   Winter Fragments pour ensemble instrumental, so...       22
# Arnold Schoenberg                                Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 ...       22
# Antonín Dvořák                                   Serenade For Strings In E, Op.22, B. 52: 1. Mod...        0
# Maurice Ravel                                    Ravel: Boléro, M. 81                           ...       22
#
# [5235 rows x 4 columns]

# %% [markdown]
# >Using PCA on a bigger dataset
# Let's look at how useful PCA can be as your datasets get bigger
#
# Sklearn `make_blobs` creates artificial datasets with distinct clusters. Specifically, it creates a specified number of clusters, each with a defined center and standard deviation, and generates a set of random data points around these cluster centers.

# %% [markdown]
# ---
# ## 5.&nbsp; Challenge: apply this to the spotify dataset 😃

# %% [markdown]
# ### 5.1.&nbsp; Explore the 10 songs dataset
#
# Import the 10 songs dataset into a new notebook and explore it like we did at the beginning of this notebook. Do you agree with the liveliness scores that certain songs have been given? Do you think the top 3 most danceable songs are the most danceable songs in the list? Ask questions of the data and see where it leads you.
#
# If you're not familiar with any of the songs, look them up on YouTube or Spotify and listen to at least 30 seconds of each song to get a feel for them. Even if you're not a music expert we can all tell the difference between gangster rap and classical, right? Look at the scores given and see if they make sense with **how these songs make you feel**.

# %%
#import libraries
import pandas as pd

# %%
url = '/Users/sadiakhanrupa/Bootcamp Main Phase/Chapter 6 Unsupervised ML/data/6.3.2_spotify_10_songs.csv'
songs_df = pd.read_csv(url, index_col=None, nrows=10)
songs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 17 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   song_name                                                                 10 non-null     object
#  1   artist                                                                    10 non-null     object
#  2   danceability                                                              10 non-null     float64
#  3   energy                                                                    10 non-null     float64
#  4   key                                                                       10 non-null     int64
#  5   loudness                                                                  10 non-null     float64
# ...

# %%
#cleaned the space remaiining in column name
songs_df.columns = songs_df.columns.str.replace(' ', '') 
print(songs_df.columns)
# Out:
# Index(['song_name', 'artist', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature', 'id', 'html'],
#       dtype='object')

# %%
to_drop = ['id', 'html', 'artist']
songs_df = songs_df.drop(columns=to_drop)
songs_df
# Out:
#                                            song_name  danceability   energy  \
# 0  My Band                                       ...         0.851  0.84900
# 1  The Real Slim Shady                           ...         0.949  0.66100
# 2  Águas De Março                                ...         0.642  0.33900
# 3  The Girl From Ipanema                         ...         0.641  0.14000
# 4  Paint It, Black                               ...         0.464  0.79500
# 5  Sultans Of Swing                              ...         0.733  0.79400
# 6  Space Raiders - Charlotte de Witte Remix      ...         0.749  0.73100
# 7  In Silence                                    ...         0.736  0.84500
# 8  Wiegenlied, Op. 49, No. 4 (Arr. for Cello and ...         0.184  0.00833
# 9  Nocturne en mi bémol majeur opus 9 n°2: Ballad...         0.387  0.04510
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
songs_df = songs_df.set_index(['song_name'])
songs_df
# Out:
#                                                     danceability   energy  \
# song_name
# My Band                                        ...         0.851  0.84900
# The Real Slim Shady                            ...         0.949  0.66100
# Águas De Março                                 ...         0.642  0.33900
# The Girl From Ipanema                          ...         0.641  0.14000
# Paint It, Black                                ...         0.464  0.79500
# Sultans Of Swing                               ...         0.733  0.79400
# Space Raiders - Charlotte de Witte Remix       ...         0.749  0.73100
# In Silence                                     ...         0.736  0.84500
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...         0.184  0.00833
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...         0.387  0.04510
#
#                                                     key  loudness  mode  \
# song_name
# ...

# %%
#top 3 most danceble songs
sorted_danceability = pd.DataFrame(songs_df['danceability'].sort_values(ascending= False))
sorted_danceability[:3]
# Out:
#                                                     danceability
# song_name
# The Real Slim Shady                            ...         0.949
# My Band                                        ...         0.851
# Space Raiders - Charlotte de Witte Remix       ...         0.749

# %%
#top songs with liveness
sorted_liveness =pd.DataFrame(songs_df['liveness'].sort_values(ascending=False))
sorted_liveness
# Out:
#                                                     liveness
# song_name
# Paint It, Black                                ...    0.3990
# Sultans Of Swing                               ...    0.3300
# My Band                                        ...    0.1160
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...    0.1120
# Space Raiders - Charlotte de Witte Remix       ...    0.1110
# In Silence                                     ...    0.1110
# Águas De Março                                 ...    0.1050
# The Girl From Ipanema                          ...    0.1050
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...    0.1040
# The Real Slim Shady                            ...    0.0454

# %% [markdown]
# ### 5.2.&nbsp; Use KMeans to group the 10 songs dataset
#
# Play around with the clustering algorithm and get familiar with it. What happens when you change the number of clusters? What number of clusters produces the best output? What happens when you change the number of the random seed?

# %%
#import the model
from sklearn.cluster import KMeans

# %%
#number of clusters = 3, random state = None
myKmeans = KMeans(n_clusters=3, random_state=None)
myKmeans.fit(songs_df)
# Out:
# /Users/sadiakhanrupa/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=3)

# %%
cluster = myKmeans.labels_
cluster
# Out:
# array([0, 0, 1, 0, 1, 0, 2, 2, 1, 0], dtype=int32)

# %%
songs_df['cluster'] = cluster
songs_df[['cluster']].sort_values(by= 'cluster')
# Out:
#                                                     cluster
# song_name
# My Band                                        ...        0
# The Real Slim Shady                            ...        0
# The Girl From Ipanema                          ...        0
# Sultans Of Swing                               ...        0
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...        0
# Águas De Março                                 ...        1
# Paint It, Black                                ...        1
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...        1
# Space Raiders - Charlotte de Witte Remix       ...        2
# In Silence                                     ...        2

# %%
#number of clusters = 4, random state = None
myKmeans_4_cluster = KMeans(n_clusters=4, random_state=None)
myKmeans_4_cluster.fit(songs_df)
cluster_4 = myKmeans_4_cluster.labels_
songs_df['cluster_4'] = cluster_4
songs_df[['cluster_4']].sort_values(by= 'cluster_4')
# Out:
# /Users/sadiakhanrupa/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#                                                     cluster_4
# song_name
# My Band                                        ...          0
# The Real Slim Shady                            ...          0
# The Girl From Ipanema                          ...          0
# Sultans Of Swing                               ...          0
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...          0
# Águas De Março                                 ...          1
# Paint It, Black                                ...          1
# Space Raiders - Charlotte de Witte Remix       ...          2
# In Silence                                     ...          2
# ...

# %%
#number of clusters = 4, random state = 0
myKmeans_4_cluster_rs0 = KMeans(n_clusters=4, random_state=0)
myKmeans_4_cluster_rs0.fit(songs_df)
cluster_4_0 = myKmeans_4_cluster_rs0.labels_
songs_df['cluster_4_0'] = cluster_4_0
songs_df[['cluster_4_0']].sort_values(by= 'cluster_4_0')
# Out:
# /Users/sadiakhanrupa/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#                                                     cluster_4_0
# song_name
# My Band                                        ...            0
# The Real Slim Shady                            ...            0
# The Girl From Ipanema                          ...            0
# Sultans Of Swing                               ...            0
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...            0
# Space Raiders - Charlotte de Witte Remix       ...            1
# In Silence                                     ...            1
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...            2
# Águas De Março                                 ...            3
# ...

# %% [markdown]
# **when random state = none, Space Raiders - Charlotte de Witte Remix was in cluster 2, when random state = 0, Space Raiders - Charlotte de Witte Remix in cluster 1**

# %%
#number of clusters = 4, random state = 42
myKmeans_4_cluster_rs42 = KMeans(n_clusters=4, random_state=42)
myKmeans_4_cluster_rs42.fit(songs_df)
cluster_4_42 = myKmeans_4_cluster_rs42.labels_
songs_df['cluster_4_42'] = cluster_4_42
songs_df[['cluster_4_42']].sort_values(by= 'cluster_4_42')
# Out:
# /Users/sadiakhanrupa/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#                                                     cluster_4_42
# song_name
# My Band                                        ...             0
# The Real Slim Shady                            ...             0
# The Girl From Ipanema                          ...             0
# Sultans Of Swing                               ...             0
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...             0
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...             1
# Águas De Março                                 ...             2
# Paint It, Black                                ...             2
# Space Raiders - Charlotte de Witte Remix       ...             3
# ...

# %%
#to_compare
songs_df.iloc[:, [-1,-2,-3]]
# Out:
#                                                     cluster_4_42  cluster_4_0  \
# song_name
# My Band                                        ...             0            0
# The Real Slim Shady                            ...             0            0
# Águas De Março                                 ...             2            3
# The Girl From Ipanema                          ...             0            0
# Paint It, Black                                ...             2            3
# Sultans Of Swing                               ...             0            0
# Space Raiders - Charlotte de Witte Remix       ...             3            1
# In Silence                                     ...             3            1
# Wiegenlied, Op. 49, No. 4 (Arr. for Cello and P...             1            2
# Nocturne en mi bémol majeur opus 9 n°2: Ballade...             0            0
#
#                                                     cluster_4
# song_name
# ...

# %% [markdown]
# **Águas De Março, Paint It, Black	, Space Raiders - Charlotte de Witte Remix, In Silence	, Wiegenlied, Op. 49, No. 4 (Arr. for Cello and Piano) [Brahms Lullaby]	are in different clusters as I have experimented with random state**

# %% [markdown]
# ### 5.3.&nbsp; Familiarise yourself with the documentation for scikit-learn
#
# We'll be using scikit-learn a lot in the coming weeks, so it's a good idea to start familiarising yourself with its documentation now. The documentation is very well written, so be sure to check it out, start with the [KMeans](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html) function that we used in this notebook. Play around with it and read up on some of the parameters that we didn't use.
